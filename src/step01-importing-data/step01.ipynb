# %%
using Plots, CSV, Dates
using DataFrames: DataFrame

#read data files using DataArrays
dataframe = CSV.read("../../data/Proccesed/DetrendedCov.csv", DataFrame)
dataframe[!,:Date] = convert.(Base.Float64,dataframe[!,:Date])

# display plot
xs = dataframe."Date"
ys = dataframe."DetrendedN1"
Plots.scatter(xs, ys, color="black", xlabel="X", ylabel="Y", label=nothing, title="Observations")
# Out:
# (process:25012): GLib-GIO-WARNING **: 11:17:25.731: Unexpectedly, UWP app `HaukeGtze.7-ZipFileManagerUnofficial_1.1900.3.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.7-ZipFileManagerUnofficial_6bk20wvc8rfx2!zFM.exe') supports 36 extensions but has no verbs
#
# (process:25012): GLib-GIO-WARNING **: 11:17:25.853: Unexpectedly, UWP app `HaukeGtze.PuTTYSSHClient_1.76.2.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.PuTTYSSHClient_6bk20wvc8rfx2!pageant.exe') supports 1 extensions but has no verbs
