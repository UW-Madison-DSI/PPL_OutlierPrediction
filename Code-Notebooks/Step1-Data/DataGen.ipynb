# %%
using  Plots, CSV
using DataFrames: DataFrame

# Disable logging, because @animate is verbose otherwise
#Logging.disable_logging(Logging.Info);
# Out:
# (process:23272): GLib-GIO-WARNING **: 12:25:01.923: Unexpectedly, UWP app `HaukeGtze.7-ZipFileManagerUnofficial_1.1900.3.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.7-ZipFileManagerUnofficial_6bk20wvc8rfx2!zFM.exe') supports 36 extensions but has no verbs
#
# (process:23272): GLib-GIO-WARNING **: 12:25:01.966: Unexpectedly, UWP app `HaukeGtze.PuTTYSSHClient_1.76.2.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.PuTTYSSHClient_6bk20wvc8rfx2!pageant.exe') supports 1 extensions but has no verbs

# %%
#using CSV package to load the CSV file
dataframe = CSV.read("../../Data/Proccesed/DetrendedCov.csv", DataFrame)
first(dataframe, 5)
# Out:
# 5×5 DataFrame
#  Row │ Column1  Date   N1     LoessN1  DetrendedN1
#      │ Int64    Int64  Int64  Float64  Float64
# ─────┼─────────────────────────────────────────────
#    1 │       1      0  63618  -3628.0    67246.0
#    2 │       2      4  11442  12206.4     -764.409
#    3 │       3      7  39145  24029.8    15115.2
#    4 │       4     10  28553  35819.2    -7266.18
#    5 │       5      9  16743  31895.1   -15152.1

# %%
Plots.scatter(dataframe."Date", dataframe."N1", color="black", xlabel="X", ylabel="Y", 
              label=nothing, title="Observations - regular data and outliers")

# %%
Plots.scatter(dataframe."Date", dataframe."DetrendedN1", color="black", xlabel="X", ylabel="Y", 
              label=nothing, title="Observations - regular data and outliers")
